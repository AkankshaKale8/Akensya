# %% [markdown]
# # Akensya — CLV regression experiment
# This notebook is for experimentation only. Export validated model artifacts to the GitHub project.

# %%
import pandas as pd
# Load the relevant CSV from the project/data folder after uploading it to Colab.
